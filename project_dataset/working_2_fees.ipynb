# %%
import pandas as pd

# %%
df1 = pd.read_csv("extract - fees - data analyst - .csv")

# %%
df1
# Out:
#           id  cash_request_id             type    status  \
# 0       6537          14941.0  instant_payment  rejected
# 1       6961          11714.0         incident  accepted
# 2      16296          23371.0  instant_payment  accepted
# 3      20775          26772.0  instant_payment  accepted
# 4      11242          19350.0  instant_payment  accepted
# ...      ...              ...              ...       ...
# 21056  12372          20262.0  instant_payment  rejected
# 21057  20768          26764.0  instant_payment  rejected
# 21058  18779          25331.0  instant_payment  rejected
# 21059  16542          23628.0  instant_payment  rejected
# 21060  13301          20982.0  instant_payment  accepted
#
#                     category  total_amount  \
# 0                        NaN           5.0
# 1      rejected_direct_debit           5.0
# 2                        NaN           5.0
# 3                        NaN           5.0
# 4                        NaN           5.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21061 non-null  int64
#  1   cash_request_id  21057 non-null  float64
#  2   type             21061 non-null  object
#  3   status           21061 non-null  object
#  4   category         2196 non-null   object
#  5   total_amount     21061 non-null  float64
#  6   reason           21061 non-null  object
#  7   created_at       21061 non-null  object
#  8   updated_at       21061 non-null  object
#  9   paid_at          15531 non-null  object
#  10  from_date        7766 non-null   object
#  11  to_date          7766 non-null   object
#  12  charge_moment    21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df1.describe()
# Out:
#                  id  cash_request_id  total_amount
# count  21061.000000     21057.000000  21061.000000
# mean   10645.355111     16318.449162      5.000237
# std     6099.315256      6656.149949      0.034453
# min        1.000000      1456.000000      5.000000
# 25%     5385.000000     11745.000000      5.000000
# 50%    10652.000000     17160.000000      5.000000
# 75%    15925.000000     21796.000000      5.000000
# max    21193.000000     27010.000000     10.000000

# %%
df1.columns
# Out:
# Index(['id', 'cash_request_id', 'type', 'status', 'category', 'total_amount',
#        'reason', 'created_at', 'updated_at', 'paid_at', 'from_date', 'to_date',
#        'charge_moment'],
#       dtype='object')

# %%
# Dropped the columns that I didn't need
df1 = df1.drop(columns=["reason","created_at","updated_at","paid_at","from_date","to_date","charge_moment"])
df1
# Out:
#           id  cash_request_id             type    status  \
# 0       6537          14941.0  instant_payment  rejected
# 1       6961          11714.0         incident  accepted
# 2      16296          23371.0  instant_payment  accepted
# 3      20775          26772.0  instant_payment  accepted
# 4      11242          19350.0  instant_payment  accepted
# ...      ...              ...              ...       ...
# 21056  12372          20262.0  instant_payment  rejected
# 21057  20768          26764.0  instant_payment  rejected
# 21058  18779          25331.0  instant_payment  rejected
# 21059  16542          23628.0  instant_payment  rejected
# 21060  13301          20982.0  instant_payment  accepted
#
#                     category  total_amount
# 0                        NaN           5.0
# 1      rejected_direct_debit           5.0
# 2                        NaN           5.0
# 3                        NaN           5.0
# 4                        NaN           5.0
# ...

# %%
# I checked how many times used each status category 
df1["status"].value_counts()
# Out:
# status
# accepted     14841
# cancelled     4938
# rejected      1194
# confirmed       88
# Name: count, dtype: int64

# %%
# for each category how many money company turned back based on the total amount.
 fee_payments = df1.groupby("status")["total_amount"].sum()
fee_payments
# Out:
#   Cell In[45], line 2
#     fee_payments = df1.groupby("status")["total_amount"].sum()
#     ^
# IndentationError: unexpected indent

# %%
total_fee_payments = df1["total_amount"].sum()
total_fee_payments
# Out:
# 105310.0

# %%
import matplotlib.pyplot as plt

status = ["accepted", "cancelled", "confirmed", "rejected"]
amounts = [74210.0, 24690.0, 440.0, 5970.0]  # Corresponding total amounts

fig, ax = plt.subplots(figsize=(9, 6))  

# Plot bar chart
ax.bar(status, amounts, color='skyblue', edgecolor="black")

ax.set_title('Categorical total fees', fontsize=16)
ax.set_xlabel('Status', fontsize=12)
ax.set_ylabel('Total Amount', fontsize=12)


plt.tight_layout()  
plt.show()
